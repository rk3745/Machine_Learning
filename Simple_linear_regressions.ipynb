# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
rk = pd.read_csv("/content/placement (1).csv")

# %%
rk
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
rk.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
plt.scatter(rk['cgpa'],rk['placement_exam_marks'])
plt.xlabel('CGPA')
plt.ylabel('placement_exam_marks(in numbers)')
# Out:
# Text(0, 0.5, 'placement_exam_marks(in numbers)')

# %%
X = rk.iloc[:,0:1]
y = rk.iloc[:,-1]
